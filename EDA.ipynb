# %% [markdown]
# ### Importing and downloading dataset

# %%
import pandas as pd
import zipfile
import kaggle

# %%
# !kaggle datasets download -d hmavrodiev/london-bike-sharing-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/hmavrodiev/london-bike-sharing-dataset
# License(s): other
# ...
#   0%|          | 0.00/165k [00:00<?, ?B/s]
# 100%|██████████| 165k/165k [00:00<00:00, 156MB/s]

# %%
zipfile_name = 'london-bike-sharing-dataset.zip'
with zipfile.ZipFile(zipfile_name, 'r') as zip_ref:
    zip_ref.extractall()

# %%
bikes = pd.read_csv('london_merged.csv')
bikes.head()
# Out:
#              timestamp  cnt   t1   t2    hum  wind_speed  weather_code  \
# 0  2015-01-04 00:00:00  182  3.0  2.0   93.0         6.0           3.0
# 1  2015-01-04 01:00:00  138  3.0  2.5   93.0         5.0           1.0
# 2  2015-01-04 02:00:00  134  2.5  2.5   96.5         0.0           1.0
# 3  2015-01-04 03:00:00   72  2.0  2.0  100.0         0.0           1.0
# 4  2015-01-04 04:00:00   47  2.0  0.0   93.0         6.5           1.0
#
#    is_holiday  is_weekend  season
# 0         0.0         1.0     3.0
# 1         0.0         1.0     3.0
# 2         0.0         1.0     3.0
# 3         0.0         1.0     3.0
# 4         0.0         1.0     3.0

# %%
print("Average bike count:", bikes['cnt'].mean())
# Out:
# Average bike count: 1143.1016423567244

# %%
bikes['cnt'].describe()

# bikes
# Out:
# count    17414.000000
# mean      1143.101642
# std       1085.108068
# min          0.000000
# 25%        257.000000
# 50%        844.000000
# 75%       1671.750000
# max       7860.000000
# Name: cnt, dtype: float64

# %%
print(len(bikes['cnt']))
# Out:
# 17414

# %%
# Example to find actual count for a timestamp in your dataframe:
actual_count = bikes.loc[bikes['timestamp'] == '2024-03-20 14:00:00', 'cnt']
print("Actual bike count:", actual_count)
# Out:
# Actual bike count: Series([], Name: cnt, dtype: int64)

# %% [markdown]
# ### Data Exploraration

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 1.3+ MB

# %%
bikes.weather_code.value_counts()
# Out:
# weather_code
# 1.0     6150
# 2.0     4034
# 3.0     3551
# 7.0     2141
# 4.0     1464
# 26.0      60
# 10.0      14
# Name: count, dtype: int64

# %%
bikes.season.value_counts()
# Out:
# season
# 0.0    4394
# 1.0    4387
# 3.0    4330
# 2.0    4303
# Name: count, dtype: int64

# %% [markdown]
# ## Renaming Columns of the dataframe (For clarity)

# %%
new_cols_dict={
    'timestamp':'time',
    'cnt':'count',
    't1':'temp_real_c',
    't2':'temp_feels_like_c',
    'hum':'humidity_percent',
    'wind_speed_kmh':'wind_speed_kph',
    'weather_code':'weather',
    'is_holiday':'is_holiday',
    'is_weekend':'is_weekend',
    'season':'season'
}

bikes.rename(columns=new_cols_dict, inplace=True)

# %%
bikes.humidity_percent = bikes.humidity_percent/100

# %%
bikes
# Out:
#                       time  count  temp_real_c  temp_feels_like_c  \
# 0      2015-01-04 00:00:00    182          3.0                2.0
# 1      2015-01-04 01:00:00    138          3.0                2.5
# 2      2015-01-04 02:00:00    134          2.5                2.5
# 3      2015-01-04 03:00:00     72          2.0                2.0
# 4      2015-01-04 04:00:00     47          2.0                0.0
# ...                    ...    ...          ...                ...
# 17409  2017-01-03 19:00:00   1042          5.0                1.0
# 17410  2017-01-03 20:00:00    541          5.0                1.0
# 17411  2017-01-03 21:00:00    337          5.5                1.5
# 17412  2017-01-03 22:00:00    224          5.5                1.5
# 17413  2017-01-03 23:00:00    139          5.0                1.0
#
#        humidity_percent  wind_speed  weather  is_holiday  is_weekend  season
# 0                 0.930         6.0      3.0         0.0         1.0     3.0
# ...

# %%
Season_dict = {
    '0.0':'Spring',
    '1.0':'Summer',
    '2.0':'Autumn',
    '3.0':'Winter'
}

weather_dict = {
    '1.0':'Clear',
    '2.0':'Scattered clouds',
    '3.0':'Broken clouds',
    '4.0':'Cloudy',
    '7.0':'Rain',
    '10.0':'Rain with thunderstorm',
    '26.0':'Snowfall'
}

bikes.season = bikes.season.astype(str)
bikes.season = bikes.season.map(Season_dict)

bikes.weather = bikes.weather.astype(str)
bikes.weather = bikes.weather.map(weather_dict)

# %%
bikes
# Out:
#                       time  count  temp_real_c  temp_feels_like_c  \
# 0      2015-01-04 00:00:00    182          3.0                2.0
# 1      2015-01-04 01:00:00    138          3.0                2.5
# 2      2015-01-04 02:00:00    134          2.5                2.5
# 3      2015-01-04 03:00:00     72          2.0                2.0
# 4      2015-01-04 04:00:00     47          2.0                0.0
# ...                    ...    ...          ...                ...
# 17409  2017-01-03 19:00:00   1042          5.0                1.0
# 17410  2017-01-03 20:00:00    541          5.0                1.0
# 17411  2017-01-03 21:00:00    337          5.5                1.5
# 17412  2017-01-03 22:00:00    224          5.5                1.5
# 17413  2017-01-03 23:00:00    139          5.0                1.0
#
#        humidity_percent  wind_speed           weather  is_holiday  is_weekend  \
# 0                 0.930         6.0     Broken clouds         0.0         1.0
# ...

# %%
bikes.to_excel('london_bikes_cleaned.xlsx', sheet_name="Data")

# %%
df = pd.read_csv('london_merged.csv')
print("Average bike count:", df['cnt'].mean())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('london_merged.csv')
#       2 print("Average bike count:", df['cnt'].mean())
#
# NameError: name 'pd' is not defined
